# %% [markdown]
# # Make Gaussian Label Dataset

# %%
import cv2
import glob
import os
import shutil
import random
import sqlite3
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from openslide import OpenSlide
from multiprocessing import Pool

# %% [markdown]
# ## Load annotation data

# %%
annotation_filepath = "databases/MITOS_WSI_CMC_CODAEL_TR_ROI.sqlite"
WSI_dir = "/raid/adachi/detection/WSI"

# %%
DB = sqlite3.connect(annotation_filepath)
file_df = pd.read_sql('SELECT * FROM Slides', DB)
label_df = pd.read_sql('SELECT * FROM Annotations', DB)

mitosis_df = label_df[label_df["agreedClass"]==2]
print(mitosis_df)
notmitosis_df = label_df[label_df["agreedClass"]==1]
print(mitosis_df.head())
coordinates_df = pd.read_sql('SELECT * FROM Annotations_coordinates', DB)
print(coordinates_df.head())
# Out:
#           uid  slide  type  agreedClass                                  guid  \
# 51         53      1     1            2  4503169c-847f-4416-852b-550fc295d243
# 57         59      1     1            2  fbb92bab-8f4d-46c7-8ea6-f0c6405c29a2
# 61         64      1     1            2  ff6adfdb-5bf8-4a3c-a686-c2d2f020c6af
# 64         67      1     1            2  26b2bd4c-ecc7-4b38-b7fa-500a9a4a5c0e
# 66         69      1     1            2  75f3c307-f7de-447f-9271-fc1714fecbfb
# ...       ...    ...   ...          ...                                   ...
# 50217  394432     19     1            2  fc57cf1c-a813-46ae-9163-f3cf63e3c47d
# 50226  394599     19     1            2  cdf3c7db-447a-4260-a02c-13f93c0f549e
# 50234  394826     19     1            2  037be2c0-89c3-4b53-a2ad-f5b7488e1835
# 50238  394935     19     1            2  d6aa8b55-40b4-43f2-a5ad-f58e04865b04
# 50258  395727     19     1            2  1d5a80e3-37f8-4103-bcd2-d2128d575d33
#
#        deleted  lastModified description
# 51           0  1.582190e+09        None
# 57           0  1.582190e+09        None
# 61           0  1.586283e+09        None
# 64           0  1.582190e+09        None
# 66           0  1.582190e+09        None
# ...        ...           ...         ...
# 50217        0  1.582190e+09        None
# 50226        0  1.582190e+09        None
# 50234        0  1.582190e+09        None
# 50238        0  1.582190e+09        None
# 50258        0  1.582190e+09        None
#
# [13907 rows x 8 columns]
#     uid  slide  type  agreedClass                                  guid  \
# 51   53      1     1            2  4503169c-847f-4416-852b-550fc295d243
# 57   59      1     1            2  fbb92bab-8f4d-46c7-8ea6-f0c6405c29a2
# 61   64      1     1            2  ff6adfdb-5bf8-4a3c-a686-c2d2f020c6af
# 64   67      1     1            2  26b2bd4c-ecc7-4b38-b7fa-500a9a4a5c0e
# 66   69      1     1            2  75f3c307-f7de-447f-9271-fc1714fecbfb
#
#     deleted  lastModified description
# 51        0  1.582190e+09        None
# 57        0  1.582190e+09        None
# 61        0  1.586283e+09        None
# 64        0  1.582190e+09        None
# 66        0  1.582190e+09        None
#    uid  coordinateX  coordinateY  slide  annoId  orderIdx  coordinateZ
# 0    1        21029         7246      1       1         1            0
# 1    2        21030         7305      1       2         1            0
# 2    3        20378         6976      1       3         1            0
# 3    4        21086         6940      1       4         1            0
# 4    5        23504         7623      1       5         1            0

# %%
test_wsi_filenames = ["4eee7b944ad5e46c60ce.svs",
                      "e09512d530d933e436d5.svs",
                      "2d56d1902ca533a5b509.svs",
                      "13528f1921d4f1f15511.svs",
                      "69a02453620ade0edefd.svs",
                      "b1bdee8e5e3372174619.svs",
                      "022857018aa597374b6c.svs"]

wsi_list = glob.glob("{}/*.svs".format(WSI_dir))
trainval_list = []
test_list = []
for wsi_path in wsi_list:
    if wsi_path.split("/")[-1] in test_wsi_filenames:
        test_list.append(wsi_path)
    else:
        trainval_list.append(wsi_path)

# %% [markdown]
# ## Make gaussian label

# %%
MULTI_NUM = 8
GAUSS_STD = 10
CROP_SIZE = 256
OVERLAP = 128

# %%
def gaussian2d(size, sigma):
    ax = np.linspace(-(size-1)/2, (size-1)/2, size)
    gauss = np.exp(-0.5 * np.square(ax) / np.square(sigma))
    kernel = np.outer(gauss, gauss)
    return kernel

kernel = gaussian2d(size=101, sigma=GAUSS_STD)
print("Gaussian std: {}".format(GAUSS_STD))
plt.imshow(kernel, cmap="gray")
# Out:
# Gaussian std: 10

# %%
dataset_dirname = "/raid/adachi/detection/gaussian_dataset"
if os.path.exists(dataset_dirname):
    shutil.rmtree(dataset_dirname)

def make_label(wsi_path, crop_size=CROP_SIZE, overlap=OVERLAP, kernel=kernel):
    filename = wsi_path.split("/")[-1]
    filedata = file_df[file_df["filename"]==filename]
    wsi_id = filedata.iat[0, 0]
    wsi = OpenSlide(wsi_path)
    wsi_w, wsi_h = wsi.dimensions
    
    if not os.path.exists("{}/{}/image".format(dataset_dirname, wsi_id)):
        os.makedirs("{}/{}/image".format(dataset_dirname, wsi_id))
    if not os.path.exists("{}/{}/label".format(dataset_dirname, wsi_id)):
        os.makedirs("{}/{}/label".format(dataset_dirname, wsi_id))
    
    print("Now processing {}".format(filename))
    
    iter_h = wsi_h//(crop_size-overlap)
    iter_w = wsi_w//(crop_size-overlap)
    
    for i in range(iter_h):
        for j in range(iter_w):
            # Coordinates of upper left of ROI
            location = (j*(crop_size-overlap), i*(crop_size-overlap))
            
            cells = coordinates_df[(coordinates_df["slide"]==wsi_id) 
                                    & (location[0] <= coordinates_df["coordinateX"])
                                    & (coordinates_df["coordinateX"] < location[0]+crop_size)
                                    & (location[1] <= coordinates_df["coordinateY"])
                                    & (coordinates_df["coordinateY"] < location[1]+crop_size)]

            label = np.zeros((crop_size, crop_size, 3), np.uint8)            

            for _, row in cells.iterrows():
                uid = int(row.annoId)
                if not mitosis_df[(mitosis_df["uid"]==uid)].empty:
                    x = row.coordinateX - location[0]
                    y = row.coordinateY - location[1]
                    for m in range(101):
                        if 0 <= int(y)-50+m < crop_size:
                            for n in range(101):
                                if 0 <= int(x)-50+n < crop_size:
                                    label[int(y)-50+m, int(x)-50+n, 0]=max(int(255*kernel[m,n]),label[int(y)-50+m, int(x)-50+n, 0])
                if not notmitosis_df[(notmitosis_df["uid"]==uid)].empty:
                    x = row.coordinateX - location[0]
                    y = row.coordinateY - location[1]
                    for m in range(101):
                        if 0 <= int(y)-50+m < crop_size:
                            for n in range(101):
                                if 0 <= int(x)-50+n < crop_size:
                                    label[int(y)-50+m, int(x)-50+n, 1]=max(int(255*kernel[m,n]),label[int(y)-50+m, int(x)-50+n, 1])
            
            # Determine the value of the third channel so that the sum of the three channels is 255.
            label[:, :, 2] = 255 - (label[:, :, 0]+label[:, :, 1])
            
            # When the object of interest is included in the image, it is stored in the dataset.
            if np.max(label[overlap//2:-(overlap//2), overlap//2:-(overlap//2), :2]==255):
                img = wsi.read_region(location, 0, (crop_size, crop_size))
                img = np.array(img, dtype=np.uint8)
                img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                cv2.imwrite("{}/{}/image/{}_{}.png".format(dataset_dirname, wsi_id, location[0], location[1]), img)
                cv2.imwrite("{}/{}/label/{}_{}.png".format(dataset_dirname, wsi_id, location[0], location[1]), label[:,:,::-1])

p = Pool(MULTI_NUM)
p.map(make_label, trainval_list)
p.close()
# Out:
# Now processing 50cf88e9a33df0c0c8f9.svsNow processing a8773be388e12df89edd.svs
#
# Now processing 2191a7aa287ce1d5dbc0.svs
# Now processing da18e7b9846e9d38034c.svsNow processing d37ab62158945f22deed.svs
#
# Now processing fa4959e484beec77543b.svsNow processing deb768e5efb9d1dcbc13.svs
#
# Now processing b1bdee8e5e3372174619.svs
# Now processing 460906c0b1fe17ea5354.svs
# Now processing 72c93e042d0171a61012.svs
# Now processing d0423ef9a648bb66a763.svs
# Now processing 084383c18b9060880e82.svs
# Now processing 3d3d04eca056556b0b26.svs
# Now processing d7a8af121d7d4f3fbf01.svs
# Now processing c4b95da36e32993289cb.svs

# %% [markdown]
# ## Check dataset

# %%
dataset_dirname = "/raid/adachi/detection/gaussian_dataset"
img_list = glob.glob("{}/*/image/*".format(dataset_dirname))
label_list = glob.glob("{}/*/label/*".format(dataset_dirname))
print(len(img_list))
row_num = 2

fig, axs = plt.subplots(row_num, 2, figsize=(20, 20))

sampling = random.sample(range(len(img_list)), k=row_num)

for i in range(row_num):
    j=sampling[i]
    img = cv2.imread(img_list[j])
    label = cv2.imread(label_list[j])
    axs[i, 0].set_title("image", fontsize=20)
    axs[i, 0].imshow(img[:,:,::-1])
    axs[i, 1].set_title("label", fontsize=20)
    axs[i, 1].imshow(label[:,:,::-1])
# Out:
# 39629

# %% [markdown]
# ## Make train data

# %%
def gauss2circle(label):
    h, w, _ = label.shape
    for y in range(h):
        for x in range(w):
            idx = np.argmax(label[y, x])
            if idx == 0:
                label[y, x] = (255, 0, 0)
            elif idx == 1:
                label[y, x] = (0, 255, 0)
            else:
                label[y, x] = (0, 0, 255)
                
    return label

# %%
dataset_dirname = "/raid/adachi/detection/gaussian_dataset"
crossval_dirname = "crossval_dataset"
if os.path.exists(crossval_dirname):
    shutil.rmtree(crossval_dirname)
if os.path.exists("{}/val.txt".format(crossval_dirname)):
    os.remove("{}/val.txt".format(crossval_dirname))
    
data_list = glob.glob("{}/*".format(dataset_dirname))
split = len(data_list)//3
for i in range(3):
    print("crossval_{}".format(i))
    val_data = data_list[split*i:split*(i+1)]
    train_image_dir = "{}/crossval_{}/train/image".format(crossval_dirname, i)
    train_label_dir = "{}/crossval_{}/train/label".format(crossval_dirname, i)
    val_image_dir = "{}/crossval_{}/val/image".format(crossval_dirname, i)
    val_label_dir = "{}/crossval_{}/val/label".format(crossval_dirname, i)
    os.makedirs(train_image_dir)
    os.makedirs(train_label_dir)
    os.makedirs(val_image_dir)
    os.makedirs(val_label_dir)
    with open("{}/val.txt".format(crossval_dirname), mode="a") as f:
        f.write("crossval_{}".format(i))
    for data_dir in data_list:
        image_list = glob.glob(data_dir+"/image/*")
        label_list = glob.glob(data_dir+"/label/*")            
        if data_dir in val_data:
            with open("{}/val.txt".format(crossval_dirname), mode="a") as f:
                f.write(" {}".format(data_dir.split("/")[-1]))
            print("val:{}".format(data_dir))
            for image_path, label_path in zip(image_list, label_list):
                shutil.copy(image_path, val_image_dir)
                shutil.copy(label_path, val_label_dir)
        else:
            print("train:{}".format(data_dir))
            for image_path, label_path in zip(image_list, label_list):
                shutil.copy(image_path, train_image_dir)
                shutil.copy(label_path, train_label_dir)
    with open("{}/val.txt".format(crossval_dirname), mode="a") as f:
        f.write("\n")
    print()
# Out:
# crossval_0
# val:/raid/adachi/detection/gaussian_dataset/16
# val:/raid/adachi/detection/gaussian_dataset/5
# val:/raid/adachi/detection/gaussian_dataset/15
# val:/raid/adachi/detection/gaussian_dataset/1
# val:/raid/adachi/detection/gaussian_dataset/2
# train:/raid/adachi/detection/gaussian_dataset/19
# train:/raid/adachi/detection/gaussian_dataset/6
# train:/raid/adachi/detection/gaussian_dataset/7
# train:/raid/adachi/detection/gaussian_dataset/11
# train:/raid/adachi/detection/gaussian_dataset/20
# train:/raid/adachi/detection/gaussian_dataset/8
# train:/raid/adachi/detection/gaussian_dataset/12
# train:/raid/adachi/detection/gaussian_dataset/13
# train:/raid/adachi/detection/gaussian_dataset/17
# train:/raid/adachi/detection/gaussian_dataset/9
#
# crossval_1
# train:/raid/adachi/detection/gaussian_dataset/16
# train:/raid/adachi/detection/gaussian_dataset/5
# train:/raid/adachi/detection/gaussian_dataset/15
# train:/raid/adachi/detection/gaussian_dataset/1
# train:/raid/adachi/detection/gaussian_dataset/2
# val:/raid/adachi/detection/gaussian_dataset/19
# val:/raid/adachi/detection/gaussian_dataset/6
# val:/raid/adachi/detection/gaussian_dataset/7
# val:/raid/adachi/detection/gaussian_dataset/11
# val:/raid/adachi/detection/gaussian_dataset/20
# train:/raid/adachi/detection/gaussian_dataset/8
# train:/raid/adachi/detection/gaussian_dataset/12
# train:/raid/adachi/detection/gaussian_dataset/13
# train:/raid/adachi/detection/gaussian_dataset/17
# train:/raid/adachi/detection/gaussian_dataset/9
#
# crossval_2
# train:/raid/adachi/detection/gaussian_dataset/16
# train:/raid/adachi/detection/gaussian_dataset/5
# train:/raid/adachi/detection/gaussian_dataset/15
# train:/raid/adachi/detection/gaussian_dataset/1
# train:/raid/adachi/detection/gaussian_dataset/2
# train:/raid/adachi/detection/gaussian_dataset/19
# train:/raid/adachi/detection/gaussian_dataset/6
# train:/raid/adachi/detection/gaussian_dataset/7
# train:/raid/adachi/detection/gaussian_dataset/11
# train:/raid/adachi/detection/gaussian_dataset/20
# val:/raid/adachi/detection/gaussian_dataset/8
# val:/raid/adachi/detection/gaussian_dataset/12
# val:/raid/adachi/detection/gaussian_dataset/13
# val:/raid/adachi/detection/gaussian_dataset/17
# val:/raid/adachi/detection/gaussian_dataset/9

# %%
dataset_dirname = "train_gauss"
img_list = glob.glob("{}/image/*".format(dataset_dirname))
label_list = glob.glob("{}/label/*".format(dataset_dirname))
print(len(img_list))
row_num = 2

fig, axs = plt.subplots(row_num, 2, figsize=(20, 20))

sampling = random.sample(range(len(img_list)), k=row_num)

for i in range(row_num):
    j=sampling[i]
    img = cv2.imread(img_list[j])
    print(img_list[j])
    label = cv2.imread(label_list[j])
    axs[i, 0].set_title("image", fontsize=20)
    axs[i, 0].imshow(img[:,:,::-1])
    axs[i, 1].set_title("label", fontsize=20)
    axs[i, 1].imshow(label[:,:,::-1])
# Out:
# 39629
# train_gauss/image/11_61184_21248.png
# train_gauss/image/16_8448_57216.png

# %%
print(len(glob.glob(train_dir+"/image/*")))
print(len(glob.glob(train_dir+"/label/*")))
# Out:
# 37025
# 37025

# %%
dataset_dirname = "/raid/adachi/detection/gaussian_dataset"
train_dir = "train_gauss"
if os.path.exists(train_dir):
    shutil.rmtree(train_dir)
    
data_list = glob.glob("{}/*".format(dataset_dirname))

train_image_dir = "{}/image".format(train_dir)
train_label_dir = "{}/label".format(train_dir)
os.makedirs(train_image_dir)
os.makedirs(train_label_dir)
for data_dir in data_list:
    image_list = glob.glob(data_dir+"/image/*")
    label_list = glob.glob(data_dir+"/label/*")            
    for image_path, label_path in zip(image_list, label_list):
        image_save_path = "{}/{}_{}".format(train_image_dir, data_dir.split("/")[-1], image_path.split("/")[-1])
        label_save_path = "{}/{}_{}".format(train_label_dir, data_dir.split("/")[-1], label_path.split("/")[-1])
        shutil.copy(image_path, image_save_path)
        shutil.copy(label_path, label_save_path)

# %%
dataset_dirname = "/raid/adachi/detection/gaussian_dataset"
train_dir = "train_circle_bin"
if os.path.exists(train_dir):
    shutil.rmtree(train_dir)
    
data_list = glob.glob("{}/*".format(dataset_dirname))

train_image_dir = "{}/image".format(train_dir)
train_label_dir = "{}/label".format(train_dir)
os.makedirs(train_image_dir)
os.makedirs(train_label_dir)
for data_dir in data_list:
    image_list = glob.glob(data_dir+"/image/*")
    label_list = glob.glob(data_dir+"/label/*")            
    for image_path, label_path in zip(image_list, label_list):
        image_save_path = "{}/{}_{}".format(train_image_dir, data_dir.split("/")[-1], image_path.split("/")[-1])
        label_save_path = "{}/{}_{}".format(train_label_dir, data_dir.split("/")[-1], label_path.split("/")[-1])
        shutil.copy(image_path, image_save_path)
        label = cv2.imread(label_path)
        label = gauss2circle(label)
        cv2.imwrite(label_save_path, label[:, :, 2])

# %%
dataset_dirname = "/raid/adachi/detection/gaussian_dataset"
train_dir = "train_gauss_bin"
if os.path.exists(train_dir):
    shutil.rmtree(train_dir)
    
data_list = glob.glob("{}/*".format(dataset_dirname))

train_image_dir = "{}/image".format(train_dir)
train_label_dir = "{}/label".format(train_dir)
os.makedirs(train_image_dir)
os.makedirs(train_label_dir)
for data_dir in data_list:
    image_list = glob.glob(data_dir+"/image/*")
    label_list = glob.glob(data_dir+"/label/*")            
    for image_path, label_path in zip(image_list, label_list):
        image_save_path = "{}/{}_{}".format(train_image_dir, data_dir.split("/")[-1], image_path.split("/")[-1])
        label_save_path = "{}/{}_{}".format(train_label_dir, data_dir.split("/")[-1], label_path.split("/")[-1])
        shutil.copy(image_path, image_save_path)
        label = cv2.imread(label_path)
        cv2.imwrite(label_save_path, label[:, :, 2])
